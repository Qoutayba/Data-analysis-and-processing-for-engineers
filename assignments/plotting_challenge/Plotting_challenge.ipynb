# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import h5py
import matplotlib.dates as mdates
import re
import sys
import os

# %% [markdown]
# ### reading Data from Both Files

# %%
stock_data_oil = pd.read_csv( 'data/BZ-NMX_oil.csv', delimiter=',\s*', engine='python' )
stock_data_oil.head()
#stock_data_oil.tail()
# Out:
#          Date  Close/Last   Volume   Open   High    Low
# 0  10/21/2021       84.61  47081.0  85.88  86.12  83.36
# 1  10/20/2021       85.82  41281.0  85.10  85.89  83.63
# 2  10/19/2021       85.08  41887.0  84.11  85.40  83.71
# 3  10/18/2021       84.33  37176.0  85.05  86.03  83.96
# 4  10/15/2021       84.86  31221.0  84.20  85.10  84.17

# %%
stock_data_gas = pd.read_csv( 'data/NG-NMX_gas.csv', delimiter=',\s*', engine='python' )
stock_data_gas.head()
#stock_data_gas.tail()
# Out:
#          Date  Close/Last    Volume   Open   High    Low
# 0  10/21/2021       5.115  100357.0  5.151  5.227  5.006
# 1  10/20/2021       5.170  130738.0  5.066  5.221  4.912
# 2  10/19/2021       5.088  147795.0  4.985  5.100  4.825
# 3  10/18/2021       4.989  161089.0  5.299  5.370  4.955
# 4  10/15/2021       5.410  175248.0  5.641  5.789  5.400

# %%
_ = pd.plotting.scatter_matrix(stock_data_gas.iloc[:,:], figsize=(12,12) )
